# %%
import time
import matplotlib.pyplot as plt
import numpy as np
from collections import deque
import pandas as pd
import dask.dataframe as dd

#%matplotlib notebook
#plt.rcParams['animation.html'] = 'jshtml'

# %%
columns = ['trade_id', 'price', 'volume_crypto', 'volume', 'timestamp', 'is_buyer_maker', 'ignore']
temp_spot = dd.read_csv('/home/donlekout/Desktop/Thesis/Data/AllCrypto/CryptoTradesBinance/'+'HOTUSDT'+'/spot/*.zip',\
     names = columns, engine = 'c', compression = 'zip')
spot = temp_spot.compute(num_workers = 8)
spot.set_index(pd.to_datetime(spot['timestamp'], unit = 'ms'), inplace = True)
spot.drop(['timestamp', 'trade_id', 'ignore'], axis = 'columns', inplace = True)
spot.sort_index(inplace = True)

# %%
def animate(i):

# %%
#%matplotlib widget
fig = plt.figure()
ax = fig.add_subplot(111)


fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig2 = plt.figure()
ax2 = fig2.add_subplot(111)

fig2.show()
# Out:
# <img src="data:image/png;base64,..." width="973">

# %%
i = 0

x,y, z = deque(maxlen = 10), deque(maxlen = 10), deque(maxlen = 10)

while True:
    x.append(i)
    y.append(i + np.random.normal())
    z.append(i+4 + np.random.normal())
    
    ax.plot(x,y)
    fig.canvas.draw()
    
    ax2.plot(x,z)
    fig2.canvas.draw()
    time.sleep(0.5)
    i +=1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_54002/1591416216.py in <module>
#      13     ax2.plot(x,z)
#      14     fig2.canvas.draw()
# ---> 15     time.sleep(0.5)
#      16     i +=1
#
# KeyboardInterrupt:
